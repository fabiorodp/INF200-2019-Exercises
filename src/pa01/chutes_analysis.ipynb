# %% [markdown]
# # Pair Programming Assignment : 1

# %% [markdown]
# In the assignment we evaluate the duration of gameplay with different number of players i.e. 1, 2 , 4 and 8 players respectively and we plot histogram for different number of players.

# %% [markdown]
# ## Team Member
# Name : Rabin Senchuri
# Email: rase@nmbu.no
#
# Name:Fábio Rodrigues Pereira
# Email: faro@nmbu.no

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt
from snakes_and_ladders import multi_game_experiment

# %%
num_players = [1, 2, 4, 8]
num_games = 100
seed = 1234567

# %%
duration = 0 * num_players

# %%
result_one = multi_game_experiment(1000, 1, seed)
result_two = multi_game_experiment(1000, 2, seed)
result_four = multi_game_experiment(1000, 4, seed)
result_eight = multi_game_experiment(1000, 8, seed)

# %%
plt.hist(result_one, bins = np.max(result_one))
plt.xlabel('Game duration')
plt.ylabel('Number of games')
plt.title("One player")
# Out:
# Text(0.5, 1.0, 'One player')

# %%
plt.hist(result_two, bins = np.max(result_two))
plt.xlabel('Game duration')
plt.ylabel('Number of games')
plt.title("Two player")
# Out:
# Text(0.5, 1.0, 'Two player')

# %%
plt.hist(result_four, bins = np.max(result_four))
plt.xlabel('Game duration')
plt.ylabel('Number of games')
plt.title("Four player")
# Out:
# Text(0.5, 1.0, 'Four player')

# %%
plt.hist(result_eight, bins = np.max(result_eight))
plt.xlabel('Game duration')
plt.ylabel('Number of games')
plt.title("Eight player")
# Out:
# Text(0.5, 1.0, 'Eight player')
